# %%
import pandas as pd
from pandas import Series,DataFrame 
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
from datetime import datetime

# %%
from __future__ import division

# %%
end = datetime.now()

# %%
start = datetime(end.year - 1, end.month,end.day)

# %%
from nsepy import get_history

# %%
sbi = get_history(symbol="SBIN", start=datetime(end.year - 1, end.month,end.day), end=datetime.now())

# %%
icici = get_history(symbol="ICICIBANK", start=datetime(end.year - 1, end.month,end.day), end=datetime.now())

# %%
pnb = get_history(symbol="PNB", start=datetime(end.year - 1, end.month,end.day), end=datetime.now())

# %%
canra = get_history(symbol="CANBK", start=datetime(end.year - 1, end.month,end.day), end=datetime.now())

# %%
jetair = get_history(symbol = "JETAIRWAYS", start = start, end = end )

# %%
sbi.describe()
# Out:
#        Prev Close        Open        High         Low        Last       Close  \
# count  245.000000  245.000000  245.000000  245.000000  245.000000  245.000000
# mean   274.994490  275.274490  279.089796  271.194694  274.993878  274.958980
# std     20.816622   20.919741   21.101190   20.521387   20.817641   20.770284
# min    233.200000  233.250000  238.800000  232.350000  233.250000  233.200000
# 25%    258.850000  259.400000  262.400000  255.150000  258.750000  258.850000
# 50%    273.000000  273.200000  276.400000  268.350000  273.000000  273.000000
# 75%    292.150000  292.850000  296.500000  288.700000  293.000000  292.150000
# max    329.900000  332.750000  332.750000  316.200000  330.450000  329.900000
#
#              VWAP        Volume      Turnover         Trades  \
# count  245.000000  2.450000e+02  2.450000e+02     245.000000
# mean   275.123347  2.272636e+07  6.291015e+14  144651.575510
# std     20.753313  1.181920e+07  3.477430e+14   62914.997094
# ...

# %%
jetair.tail()
# Out:
#                 Symbol Series  Prev Close   Open    High     Low    Last  \
# Date
# 2018-12-31  JETAIRWAYS     EQ      276.60  281.0  283.20  275.55  278.00
# 2019-01-01  JETAIRWAYS     EQ      277.45  280.1  284.45  276.35  280.70
# 2019-01-02  JETAIRWAYS     EQ      280.80  272.0  278.35  260.50  261.45
# 2019-01-03  JETAIRWAYS     EQ      263.55  261.0  261.45  245.10  246.25
# 2019-01-04  JETAIRWAYS     EQ      247.20  242.0  250.25  236.10  244.80
#
#              Close    VWAP    Volume      Turnover  Trades  \
# Date
# 2018-12-31  277.45  279.63   5634160  1.575504e+14   48164
# 2019-01-01  280.80  281.84   7699462  2.170016e+14   63338
# 2019-01-02  263.55  269.30  11588833  3.120835e+14   92077
# 2019-01-03  247.20  252.03  12487699  3.147269e+14  106548
# 2019-01-04  245.20  242.53  18709843  4.537677e+14  135195
#
#             Deliverable Volume  %Deliverble
# Date
# 2018-12-31              475032       0.0843
# 2019-01-01              347654       0.0452
# ...

# %%
sbi.head()
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2018-01-08   SBIN     EQ      306.35  307.20  309.50  305.00  306.05  305.80
# 2018-01-09   SBIN     EQ      305.80  307.50  309.50  303.30  303.90  304.30
# 2018-01-10   SBIN     EQ      304.30  304.65  305.85  300.00  301.05  301.10
# 2018-01-11   SBIN     EQ      301.10  300.90  303.00  300.00  302.15  302.20
# 2018-01-12   SBIN     EQ      302.20  304.65  304.65  300.55  302.50  302.25
#
#               VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2018-01-08  306.58  13557197  4.156338e+14  108289             7093201
# 2018-01-09  305.88  15574755  4.763935e+14  110914             6339261
# 2018-01-10  302.25  13064599  3.948825e+14  122547             5378392
# 2018-01-11  301.97  12299087  3.713983e+14   93067             5685528
# 2018-01-12  302.54  17594228  5.322941e+14  101812            10646451
#
#             %Deliverble
# Date
# 2018-01-08       0.5232
# ...

# %%
sbi['Close'].plot(legend=True,figsize=(10,4))

# %%
sbi['Volume'].plot(legend=True,figsize=(10,4))

# %%
ma_day = [10,20,50]

for ma in ma_day:
    column_name = "MA for %s days" %(str(ma))
    sbi[column_name]=pd.rolling_mean(sbi['Close'],ma)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-76ca811edc45> in <module>()
#       3 for ma in ma_day:
#       4     column_name = "MA for %s days" %(str(ma))
# ----> 5     sbi[column_name]=pd.rolling_mean(sbi['Close'],ma)
#
# AttributeError: 'module' object has no attribute 'rolling_mean'

# %%
sbi["MA for 10 days"]=pd.rolling_mean(sbi['Close'],10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-0f8093a4b759> in <module>()
# ----> 1 sbi["MA for 10 days"]=pd.rolling_mean(sbi['Close'],10)
#
# AttributeError: 'module' object has no attribute 'rolling_mean'

# %%
sbi["MA for 10 days"]=sbi['Close'].rolling(10).mean()

# %%
sbi[['Close','MA for 10 days']].plot(subplots=False,figsize=(10,4))

# %%
# We'll use pct_change to find the percent change for each day
sbi['Daily Return'] = sbi['Close'].pct_change()
# Then we'll plot the daily return percentage
sbi['Daily Return'].plot(figsize=(20,4),legend=True, linestyle = '--', color = 'green')

sbi['Daily Return'].plot(figsize=(20,4),legend=True,marker='o', linestyle = ' ', color = 'black')

# %%
sbi['Daily Return'].hist()

# %%
sns.distplot(sbi['Daily Return'].dropna(),bins=100,color='purple')
# Out:
# C:\Users\Ravi\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
closing_df =DataFrame()

# %%
closing_df['sbi']=sbi['Close']

# %%
closing_df.head()
# Out:
#                sbi
# Date
# 2018-01-08  305.80
# 2018-01-09  304.30
# 2018-01-10  301.10
# 2018-01-11  302.20
# 2018-01-12  302.25

# %%
closing_df['icici']=icici['Close']

# %%
closing_df['pnb']=pnb['Close']

# %%
closing_df['canra']=canra['Close']

# %%
closing_df['jetairways'] = jetair['Close']

# %%
closing_df.head()
# Out:
#                sbi   icici     pnb   canra  jetairways
# Date
# 2018-01-08  305.80  314.15  175.70  364.75      866.05
# 2018-01-09  304.30  312.60  174.65  364.70      837.60
# 2018-01-10  301.10  312.00  170.65  354.65      843.50
# 2018-01-11  302.20  309.50  172.75  355.50      838.70
# 2018-01-12  302.25  317.70  174.20  353.95      827.25

# %%
bank_rets = closing_df.pct_change()

# %%
bank_rets
# Out:
#                  sbi     icici       pnb     canra  jetairways
# Date
# 2018-01-08       NaN       NaN       NaN       NaN         NaN
# 2018-01-09 -0.004905 -0.004934 -0.005976 -0.000137   -0.032850
# 2018-01-10 -0.010516 -0.001919 -0.022903 -0.027557    0.007044
# 2018-01-11  0.003653 -0.008013  0.012306  0.002397   -0.005691
# 2018-01-12  0.000165  0.026494  0.008394 -0.004360   -0.013652
# 2018-01-15  0.001158  0.036512 -0.011768  0.001130   -0.007555
# 2018-01-16 -0.021315  0.014576 -0.038339 -0.041908   -0.037333
# 2018-01-17  0.036975  0.027387  0.060405  0.044919    0.039160
# 2018-01-18 -0.012537  0.008449 -0.028767 -0.015363   -0.036588
# 2018-01-19  0.019786  0.021522  0.034604  0.038362    0.002464
# 2018-01-22 -0.008892 -0.005939 -0.002268  0.000689   -0.012355
# 2018-01-23  0.037847  0.030725  0.055682  0.031823    0.015701
# 2018-01-24  0.037095 -0.026359  0.047632  0.012684   -0.026832
# 2018-01-25 -0.050773  0.022821 -0.070640 -0.047198   -0.011042
# ...

# %%
sns.jointplot('sbi','pnb',bank_rets,kind='scatter',color='seagreen')
# Out:
# C:\Users\Ravi\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Ravi\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.pairplot(bank_rets.dropna())

# %%
sbi_oc_change = DataFrame()

# %%
sbi_oc_change['Open'] = sbi['Open']

# %%
sbi_oc_change['Close'] = sbi['Close']

# %%
sbi_oc_change.head()
# Out:
#               Open   Close
# Date
# 2018-01-08  307.20  305.80
# 2018-01-09  307.50  304.30
# 2018-01-10  304.65  301.10
# 2018-01-11  300.90  302.20
# 2018-01-12  304.65  302.25

# %%
sbi_oc_change['Change'] = (sbi_oc_change.Close - sbi_oc_change.Open)

# %%
jetair_change = DataFrame()

# %%
jetair_change['change'] = jetair['Close'] - jetair['Open']
jetair_change.tail()
# Out:
#             change
# Date
# 2018-12-31   -3.55
# 2019-01-01    0.70
# 2019-01-02   -8.45
# 2019-01-03  -13.80
# 2019-01-04    3.20

# %%
sbi_oc_change.tail()
# Out:
#              Open   Close  Change
# Date
# 2018-12-31  297.2  295.90   -1.30
# 2019-01-01  297.5  299.60    2.10
# 2019-01-02  299.1  293.90   -5.20
# 2019-01-03  295.0  291.10   -3.90
# 2019-01-04  292.1  297.65    5.55

# %%
#alternate way of above
sbi_nw = DataFrame(sbi, columns=['Open', 'Close'])
sbi_nw.tail()
# Out:
#              Open   Close
# Date
# 2018-12-31  297.2  295.90
# 2019-01-01  297.5  299.60
# 2019-01-02  299.1  293.90
# 2019-01-03  295.0  291.10
# 2019-01-04  292.1  297.65

# %%
nifty_next50 = get_history(symbol="NIFTY NEXT 50",
                            start=start,
                            end =end,
                            index=True)

# %%
nifty_next50.tail()
# Out:
#                 Open      High       Low     Close       Volume      Turnover
# Date
# 2018-12-31  28161.30  28261.00  28110.50  28178.80  119740678.0  3.181620e+10
# 2019-01-01  28243.95  28252.20  27988.60  28111.65  100916543.0  2.354600e+10
# 2019-01-02  28074.05  28188.40  27801.75  27876.95  167334185.0  3.410280e+10
# 2019-01-03  27874.05  28045.30  27630.20  27674.65  175238949.0  3.362200e+10
# 2019-01-04  27707.20  27842.75  27533.90  27719.50  163387940.0  3.295060e+10

# %%
sbi.ix[246]
# Out:
# C:\Users\Ravi\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-59-75612889e7d2> in <module>()
# ----> 1 sbi.ix[246]
#
# C:\Users\Ravi\Anaconda3\lib\site-packages\pandas\core\indexing.pyc in __getitem__(self, key)
#     120
#     121             key = com._apply_if_callable(key, self.obj)
# --> 122             return self._getitem_axis(key, axis=axis)
#     123
#     124     def _get_label(self, label, axis=None):
#
# C:\Users\Ravi\Anaconda3\lib\site-packages\pandas\core\indexing.pyc in _getitem_axis(self, key, axis)
# ...

# %%
sns.corrplot(bank_rets.dropna(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-3069cc6140c1> in <module>()
# ----> 1 sns.corrplot(bank_rets.dropna(),annot=True)
#
# AttributeError: 'module' object has no attribute 'corrplot'

# %%
# Set up our figure by naming it returns_fig, call PairPLot on the DataFrame
returns_fig = sns.PairGrid(bank_rets.dropna())

# Using map_upper we can specify what the upper triangle will look like.
returns_fig.map_upper(plt.scatter)

# We can also define the lower triangle in the figure, inclufing the plot type (kde) or the color map (BluePurple)
returns_fig.map_lower(sns.kdeplot,cmap='cool_d')

# Finally we'll define the diagonal as a series of histogram plots of the daily return
returns_fig.map_diag(plt.hist,bins=30)
# Out:
# C:\Users\Ravi\Anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'color', 'label'
#   s)
# C:\Users\Ravi\Anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'color', 'label'
#   s)
# C:\Users\Ravi\Anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'color', 'label'
#   s)
# C:\Users\Ravi\Anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'color', 'label'
#   s)
# C:\Users\Ravi\Anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'color', 'label'
#   s)
# C:\Users\Ravi\Anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'color', 'label'
#   s)
# ...

# %%
# Set up our figure by naming it returns_fig, call PairPLot on the DataFrame
returns_fig = sns.PairGrid(closing_df)

# Using map_upper we can specify what the upper triangle will look like.
returns_fig.map_upper(plt.scatter,color='purple')

# We can also define the lower triangle in the figure, inclufing the plot type (kde) or the color map (BluePurple)
returns_fig.map_lower(sns.kdeplot,cmap='cool_d')

# Finally we'll define the diagonal as a series of histogram plots of the closing price
returns_fig.map_diag(plt.hist,bins=30)
# Out:
# C:\Users\Ravi\Anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'color', 'label'
#   s)
# C:\Users\Ravi\Anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'color', 'label'
#   s)
# C:\Users\Ravi\Anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'color', 'label'
#   s)
# C:\Users\Ravi\Anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'color', 'label'
#   s)
# C:\Users\Ravi\Anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'color', 'label'
#   s)
# C:\Users\Ravi\Anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'color', 'label'
#   s)
# ...

# %%
from seaborn.regression import corrplot
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-63-996cbf694a31> in <module>()
# ----> 1 from seaborn.regression import corrplot
#
# ImportError: cannot import name corrplot

# %%
# Let's go ahead and use sebron for a quick correlation plot for the daily returns
sns.corrplot(bank_rets.dropna(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-640a94d7f6a3> in <module>()
#       1 # Let's go ahead and use sebron for a quick correlation plot for the daily returns
# ----> 2 sns.corrplot(bank_rets.dropna(),annot=True)
#
# AttributeError: 'module' object has no attribute 'corrplot'

# %%
# Let's start by defining a new DataFrame as a clenaed version of the oriignal tech_rets DataFrame
rets = bank_rets.dropna()

area = np.pi*20

plt.scatter(rets.mean(), rets.std(),alpha = 0.5,s =area)

# Set the x and y limits of the plot (optional, remove this if you don't see anything in your plot)
#plt.ylim([0.01,0.025])
#plt.xlim([-0.003,0.004])

#Set the plot axis titles
plt.xlabel('Expected returns')
plt.ylabel('Risk')

# Label the scatter plots, for more info on how this is done, chekc out the link below
# http://matplotlib.org/users/annotations_guide.html
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (50, 50),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        arrowprops = dict(arrowstyle = '-', connectionstyle = 'arc3,rad=-0.3'))

# %%
sbi.head()
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2018-01-08   SBIN     EQ      306.35  307.20  309.50  305.00  306.05  305.80
# 2018-01-09   SBIN     EQ      305.80  307.50  309.50  303.30  303.90  304.30
# 2018-01-10   SBIN     EQ      304.30  304.65  305.85  300.00  301.05  301.10
# 2018-01-11   SBIN     EQ      301.10  300.90  303.00  300.00  302.15  302.20
# 2018-01-12   SBIN     EQ      302.20  304.65  304.65  300.55  302.50  302.25
#
#               VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2018-01-08  306.58  13557197  4.156338e+14  108289             7093201
# 2018-01-09  305.88  15574755  4.763935e+14  110914             6339261
# 2018-01-10  302.25  13064599  3.948825e+14  122547             5378392
# 2018-01-11  301.97  12299087  3.713983e+14   93067             5685528
# 2018-01-12  302.54  17594228  5.322941e+14  101812            10646451
#
#             %Deliverble  MA for 10 days  Daily Return
# Date
# ...

# %%
sbi.tail()
# Out:
#            Symbol Series  Prev Close   Open    High     Low    Last   Close  \
# Date
# 2018-12-31   SBIN     EQ       294.8  297.2  298.25  295.50  295.65  295.90
# 2019-01-01   SBIN     EQ       295.9  297.5  300.70  293.85  300.70  299.60
# 2019-01-02   SBIN     EQ       299.6  299.1  302.50  293.10  293.80  293.90
# 2019-01-03   SBIN     EQ       293.9  295.0  295.55  290.10  291.05  291.10
# 2019-01-04   SBIN     EQ       291.1  292.1  299.00  291.50  297.30  297.65
#
#               VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2018-12-31  296.50   9526067  2.824443e+14   81758             2618550
# 2019-01-01  296.77  11837127  3.512877e+14   69723             1668134
# 2019-01-02  298.20  25559853  7.622010e+14  162196             7019907
# 2019-01-03  292.87  17548347  5.139324e+14  110626             6361787
# 2019-01-04  296.18  19514041  5.779686e+14  142962             4963982
#
#             %Deliverble  MA for 10 days  Daily Return
# Date
# ...

# %%
# Note the use of dropna() here, otherwise the NaN values can't be read by seaborn
sns.distplot(sbi['Daily Return'].dropna(),bins=100,color='purple')
# Out:
# C:\Users\Ravi\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# The 0.05 empirical quantile of daily returns
rets['icici'].quantile(0.05)
# Out:
# -0.02740644567839745

# %%
rets['sbi'].quantile(0.05)
# Out:
# -0.028354397251508727

# %%
infy = get_history(symbol="INFY", start = start, end = end)

# %%
infy.head()
# Out:
#            Symbol Series  Prev Close     Open    High      Low     Last  \
# Date
# 2018-01-08   INFY     EQ     1012.00  1024.90  1039.0  1020.05  1035.20
# 2018-01-09   INFY     EQ     1036.05  1040.00  1044.9  1028.90  1039.00
# 2018-01-10   INFY     EQ     1041.35  1046.80  1056.0  1033.05  1053.00
# 2018-01-11   INFY     EQ     1052.25  1055.25  1083.4  1055.25  1076.50
# 2018-01-12   INFY     EQ     1075.80  1085.80  1085.9  1070.55  1078.65
#
#               Close     VWAP   Volume      Turnover  Trades  \
# Date
# 2018-01-08  1036.05  1029.31  2797345  2.879337e+14   73704
# 2018-01-09  1041.35  1036.46  4974118  5.155470e+14  119611
# 2018-01-10  1052.25  1043.96  4734317  4.942421e+14  100562
# 2018-01-11  1075.80  1069.86  8387735  8.973697e+14  134085
# 2018-01-12  1078.45  1077.02  9008264  9.702069e+14  138377
#
#             Deliverable Volume  %Deliverble
# Date
# 2018-01-08             1672022       0.5977
# 2018-01-09             3285996       0.6606
# ...

# %%
rets['pnb'].quantile(0.05)
# Out:
# -0.04864280200142966

# %%
# Set up our time horizon
days = 365

# Now our delta
dt = 1/days

# Now let's grab our mu (drift) from the expected return data we got for AAPL
mu = rets.mean()['sbi']

# Now let's grab the volatility of the stock from the std() of the average return
sigma = rets.std()['sbi']

# %%
def stock_monte_carlo(start_price,days,mu,sigma):
 #   ''' This function takes in starting stock price, days of simulation,mu,sigma, and returns simulated price array'''
    
    # Define a price array
    price = np.zeros(days)
    price[0] = start_price
    # Schok and Drift
    shock = np.zeros(days)
    drift = np.zeros(days)
    
    # Run price array for number of days
    for x in range(1,days):
        
        # Calculate Schock
        shock[x] = np.random.normal(loc=mu * dt, scale=sigma * np.sqrt(dt))
        # Calculate Drift
        drift[x] = mu * dt
        # Calculate Price
        price[x] = price[x-1] + (price[x-1] * (drift[x] + shock[x]))
        
    return price

# %%
start_price = 308

for run in range(100):
    plt.plot(stock_monte_carlo(start_price,days,mu,sigma))
plt.xlabel("Days")
plt.ylabel("Price")  
plt.title('Monte Carlo Analysis for SBI')
# Out:
# Text(0.5,1,'Monte Carlo Analysis for SBI')

# %%
# Set a large numebr of runs
runs = 10000

# Create an empty matrix to hold the end price data
simulations = np.zeros(runs)

# Set the print options of numpy to only display 0-5 points from an array to suppress output
np.set_printoptions(threshold=5)

for run in range(runs):    
    # Set the simulation data point as the last stock price for that run
    simulations[run] = stock_monte_carlo(start_price,days,mu,sigma)[days-1];

# %%
# Now we'lll define q as the 1% empirical qunatile, this basically means that 99% of the values should fall between here
q = np.percentile(simulations, 1)
    
# Now let's plot the distribution of the end prices
plt.hist(simulations,bins=200)

# Using plt.figtext to fill in some additional information onto the plot

# Starting Price
plt.figtext(0.6, 0.8, s="Start price: $%.2f" %start_price)
# Mean ending price
plt.figtext(0.6, 0.7, "Mean final price: $%.2f" % simulations.mean())

# Variance of the price (within 99% confidence interval)
plt.figtext(0.6, 0.6, "VaR(0.99): $%.2f" % (start_price - q,))

# Display 1% quantile
plt.figtext(0.15, 0.6, "q(0.99): $%.2f" % q)

# Plot a line at the 1% quantile result
plt.axvline(x=q, linewidth=4, color='r')

# Title
plt.title(u"Final price distribution for State Bank of India after %s days" % days, weight='bold');
